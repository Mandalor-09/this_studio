# %%
import pandas as pd

# %%
df = pd.read_csv("dataset/cleaned_data.csv")

# %%
df = df.iloc[:,1:]

# %%
df.head(2)
# Out:
#   Product_Company_Name          Product_Category      Product_Name  \
# 0                Apple     Electronics , Laptops    MacBook Air M1
# 1               Google  Electronics , Smart Home  Google Nest Wifi
#
#                                  Product_Description  \
# 0  The MacBook Air M1 is a powerful and portable ...
# 1  Introducing the Google Nest Wifi, the next gen...
#
#                          Product_Color       Product_Size  \
# 0  Space Gray, Silver, Gold, Rose Gold          13 inches
# 1                     Snow, Sand, Mist  One size fits all
#
#   Product_Original_Price Product_Discounted_Price Product_Additional_Discount  \
# 0                $999.00                  $899.00                          5%
# 1                $169.99                  $149.99                         10%
#
#    Average_Rating                                            Reviews  \
# 0             4.8  {'user1': "This laptop is amazing! It's so fas...
# ...

# %%
def product_name_list(df):
    product_name = df['Product_Name'].to_list()
    return product_name

# %%
product_name = product_name_list(df)
product_name
# Out:
# ['MacBook Air M1',
#  'Google Nest Wifi',
#  'Beats Studio3 Wireless Noise Cancelling Headphones - Shadow Gray',
#  'Apple Watch Ultra - 49mm - Alpine Loop - Starlight',
#  'Apple Watch Series 8',
#  'Google Nest Hub Max',
#  'Samsung Galaxy S21 Ultra',
#  'Smart Watch',
#  'Apple MacBook Air M2 - 13.6-inch Liquid Retina Display - 8-core CPU - 8-core GPU - 256GB SSD - Space Gray',
#  'Sony Bravia XR A80J OLED TV',
#  'High-Performance Laptop with Advanced Features',
#  'Samsung Galaxy Z Fold4 5G - 1TB - Phantom Black',
#  'TechGear Pro X Laptop',
#  'Smartphone',
#  'Samsung The Frame TV',
#  'Google Nest Hub Max',
#  'ABC2021 - The Ultimate Smartphone Experience',
#  'Google Nest Hub (2nd Gen)',
#  'Sony Bravia XR A80J OLED TV',
#  'Smartphone',
#  'XYZ Wireless Headphones',
#  'Instant Pot Duo Plus',
#  'ABC Smart TV',
#  'Google Nest Hub Max',
#  'Beats Studio Buds - True Wireless Noise Cancelling Earbuds - Red',
#  'Smart LED TV with Built-in Streaming Services',
# ...
